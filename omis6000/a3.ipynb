# %%
from gurobipy import GRB
import gurobipy as gb
import pandas as pd
import random
import numpy as np

# %%
distributions = pd.read_csv('/Users/frieda/Desktop/distributions.csv')
cost_matrix = pd.read_csv('/Users/frieda/Desktop/cost_matrix.csv')

# %%
# Display descriptive statistics
print("Distribution statistics:")
print(distributions.describe())
print("\nCost matrix statistics:")
print(cost_matrix.describe())

# Model parameters
n = distributions['n']
p = distributions['p']
num_stores = cost_matrix.shape[0]

# Initialize model 
model = gb.Model("Baffin Bay")

# Total objectives and sum of decision variables
total_objectives = 0
total_capacities = [0] * num_stores

# Number of trials
num_trials = 50

# Scenarios per trial
num_scenarios = 100
    
for _ in range(num_trials):

    # Add common capacity decision variables
    y = model.addVars(num_stores, lb=0, vtype=gb.GRB.INTEGER, name="order")

    # Deviational variables in the average model 
    d_plus = model.addVars(num_stores, num_scenarios, lb=0, vtype=gb.GRB.INTEGER, name="excess_inventory")
    d_minus = model.addVars(num_stores, num_scenarios, lb=0, vtype=gb.GRB.INTEGER, name="excess_demand")    
    
    # Deterministic objective function 
    underage_cost = gb.quicksum((24.44) * d_minus[i, n] for i in range(num_stores) for n in range(num_scenarios)) / num_scenarios
    overage_cost = gb.quicksum((25.55) * d_plus[i, n] for i in range(num_stores) for n in range(num_scenarios)) / num_scenarios
    model.setObjective(underage_cost + overage_cost, gb.GRB.MINIMIZE)
    
    # Demand constraint
    for s in range(num_scenarios):
        for i in range(num_stores):
            model.addConstr(y[i] + d_minus[i, s] == np.random.binomial(n[i], p[i]) + d_plus[i, s])

    # Solve the problem optimally
    model.optimize()
    
    # Update running total
    total_objectives += model.objVal
    total_capacities = [total_capacities[i] + y[i].x for i in range(num_stores)]
    
    # Reset the model for the next trial
    model.reset(0)
    
# Output results
print("Average Objective: ", total_objectives / num_trials)
for idx, capacity in enumerate(total_capacities):
    print(f"Average Optimal Capacity at store {idx}: {capacity / num_trials}")
# Out:
# Distribution statistics:
#                 n          p        Mean
# count   15.000000  15.000000   15.000000
# mean   116.933333   0.779167   92.022030
# std     19.185064   0.129295   23.857183
# min     82.000000   0.580407   51.816857
# 25%    104.000000   0.682420   74.591805
# 50%    119.000000   0.780886   98.315728
# 75%    127.000000   0.864052  112.343791
# max    147.000000   0.992744  121.847557
#
# Cost matrix statistics:
#                0          1          2          3          4          5  \
# count  15.000000  15.000000  15.000000  15.000000  15.000000  15.000000
# mean    1.857698   1.581392   1.865505   1.762188   1.752358   1.951037
# std     0.681176   0.545082   0.641201   0.596589   0.642975   0.703752
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     1.555797   1.356235   1.591919   1.520011   1.563868   1.850283
# 50%     1.841806   1.720943   2.092072   1.901807   1.821132   1.903692
# 75%     2.208821   1.916440   2.282031   2.124497   2.209774   2.363022
# max     2.856943   2.266448   2.658306   2.382201   2.586485   2.925275
#
#                6          7          8          9         10         11  \
# count  15.000000  15.000000  15.000000  15.000000  15.000000  15.000000
# mean    1.752970   1.893064   1.729042   1.906698   1.770498   1.882887
# std     0.580557   0.687150   0.578247   0.686792   0.585092   0.608763
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     1.518317   1.603234   1.630516   1.725445   1.624638   1.700837
# 50%     1.995907   1.968242   1.855567   2.031147   1.898910   1.961153
# 75%     2.078196   2.298552   2.023565   2.299280   2.119803   2.215823
# max     2.341547   2.698317   2.361799   2.754371   2.361799   2.611285
#
#               12         13         14
# count  15.000000  15.000000  15.000000
# mean    2.060359   1.953078   1.613819
# std     0.717512   0.674637   0.556922
# min     0.000000   0.000000   0.000000
# 25%     1.780399   1.846086   1.486728
# 50%     2.341547   2.012707   1.619578
# 75%     2.489492   2.274935   1.915513
# max     2.856943   2.925275   2.365839
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 1500 rows, 3015 columns and 4500 nonzeros
# Model fingerprint: 0x8857cfe0
# Variable types: 0 continuous, 3015 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33767.770400
# Presolve removed 1475 rows and 2989 columns
# Presolve time: 0.02s
# Presolved: 25 rows, 26 columns, 50 nonzeros
# Found heuristic solution: objective 3505.4213000
# Variable types: 0 continuous, 26 integer (0 binary)
#
# Root relaxation: objective 1.211836e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1211.8361000 1211.83610  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1211.84 3505.42 33767.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.211836100000e+03, best bound 1.211836100000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 3000 rows, 6030 columns and 9000 nonzeros
# Model fingerprint: 0x74842a57
# Variable types: 0 continuous, 6030 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33787.078000
# Presolve removed 2975 rows and 6004 columns
# Presolve time: 0.02s
# Presolved: 25 rows, 26 columns, 50 nonzeros
# Found heuristic solution: objective 2649.6675000
# Variable types: 0 continuous, 26 integer (0 binary)
#
# Root relaxation: objective 1.152604e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1152.6043000 1152.60430  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.21 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1152.6 2649.67 33787.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.152604300000e+03, best bound 1.152604300000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 4500 rows, 9045 columns and 13500 nonzeros
# Model fingerprint: 0x620fbde0
# Variable types: 0 continuous, 9045 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33723.289600
# Presolve removed 4477 rows and 9021 columns
# Presolve time: 0.03s
# Presolved: 23 rows, 24 columns, 46 nonzeros
# Found heuristic solution: objective 3423.5031000
# Variable types: 0 continuous, 24 integer (0 binary)
#
# Root relaxation: objective 1.192685e+03, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1192.6849000 1192.68490  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.19 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1192.68 3423.5 33723.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.192684900000e+03, best bound 1.192684900000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 6000 rows, 12060 columns and 18000 nonzeros
# Model fingerprint: 0xba3bb27b
# Variable types: 0 continuous, 12060 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33703.982000
# Presolve removed 5974 rows and 12033 columns
# Presolve time: 0.02s
# Presolved: 26 rows, 27 columns, 52 nonzeros
# Found heuristic solution: objective 3554.3899000
# Variable types: 0 continuous, 27 integer (0 binary)
#
# Root relaxation: objective 1.247862e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1247.8624000 1247.86240  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.11 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1247.86 3554.39 33704
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.247862400000e+03, best bound 1.247862400000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 7500 rows, 15075 columns and 22500 nonzeros
# Model fingerprint: 0x203b341b
# Variable types: 0 continuous, 15075 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33708.625600
# Presolve removed 7477 rows and 15051 columns
# Presolve time: 0.03s
# Presolved: 23 rows, 24 columns, 46 nonzeros
# Found heuristic solution: objective 3534.6486000
# Variable types: 0 continuous, 24 integer (0 binary)
#
# Root relaxation: objective 1.229066e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1229.0658000 1229.06580  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.24 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1229.07 3534.65 33708.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.229065800000e+03, best bound 1.229065800000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 9000 rows, 18090 columns and 27000 nonzeros
# Model fingerprint: 0x959da581
# Variable types: 0 continuous, 18090 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33758.238800
# Presolve removed 8977 rows and 18066 columns
# Presolve time: 0.03s
# Presolved: 23 rows, 24 columns, 46 nonzeros
# Found heuristic solution: objective 2734.3056000
# Variable types: 0 continuous, 24 integer (0 binary)
#
# Root relaxation: objective 1.188307e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1188.3073000 1188.30730  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.12 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1188.31 2734.31 33758.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.188307300000e+03, best bound 1.188307300000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 10500 rows, 21105 columns and 31500 nonzeros
# Model fingerprint: 0xb83c6490
# Variable types: 0 continuous, 21105 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33720.356800
# Presolve removed 10476 rows and 21080 columns
# Presolve time: 0.03s
# Presolved: 24 rows, 25 columns, 48 nonzeros
# Found heuristic solution: objective 2728.4172000
# Variable types: 0 continuous, 25 integer (0 binary)
#
# Root relaxation: objective 1.222856e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1222.8557000 1222.85570  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.12 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1222.86 2728.42 33720.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.222855700000e+03, best bound 1.222855700000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 12000 rows, 24120 columns and 36000 nonzeros
# Model fingerprint: 0x4fbcc7f7
# Variable types: 0 continuous, 24120 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33711.314000
# Presolve removed 11976 rows and 24095 columns
# Presolve time: 0.04s
# Presolved: 24 rows, 25 columns, 48 nonzeros
# Found heuristic solution: objective 2728.2624000
# Variable types: 0 continuous, 25 integer (0 binary)
#
# Root relaxation: objective 1.188318e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1188.3180000 1188.31800  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.15 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1188.32 2728.26 33711.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.188318000000e+03, best bound 1.188318000000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 13500 rows, 27135 columns and 40500 nonzeros
# Model fingerprint: 0x44e9bbd4
# Variable types: 0 continuous, 27135 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33755.794800
# Presolve removed 13477 rows and 27111 columns
# Presolve time: 0.04s
# Presolved: 23 rows, 24 columns, 46 nonzeros
# Found heuristic solution: objective 3522.4399000
# Variable types: 0 continuous, 24 integer (0 binary)
#
# Root relaxation: objective 1.194417e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1194.4167000 1194.41670  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.12 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1194.42 3522.44 33755.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.194416700000e+03, best bound 1.194416700000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 15000 rows, 30150 columns and 45000 nonzeros
# Model fingerprint: 0xe89f31c9
# Variable types: 0 continuous, 30150 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33760.927200
# Presolve removed 14979 rows and 30128 columns
# Presolve time: 0.07s
# Presolved: 21 rows, 22 columns, 42 nonzeros
# Found heuristic solution: objective 3475.2481000
# Variable types: 0 continuous, 22 integer (0 binary)
#
# Root relaxation: objective 1.143671e+03, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1143.6705000 1143.67050  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.27 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1143.67 3475.25 33760.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.143670500000e+03, best bound 1.143670500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 16500 rows, 33165 columns and 49500 nonzeros
# Model fingerprint: 0x2e84d6a6
# Variable types: 0 continuous, 33165 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33703.004400
# Presolve removed 16474 rows and 33138 columns
# Presolve time: 0.05s
# Presolved: 26 rows, 27 columns, 52 nonzeros
# Found heuristic solution: objective 2751.0568000
# Variable types: 0 continuous, 27 integer (0 binary)
#
# Root relaxation: objective 1.237552e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1237.5520000 1237.55200  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.23 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1237.55 2751.06 33703
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.237552000000e+03, best bound 1.237552000000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 18000 rows, 36180 columns and 54000 nonzeros
# Model fingerprint: 0x728a899e
# Variable types: 0 continuous, 36180 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33680.764000
# Presolve removed 17975 rows and 36154 columns
# Presolve time: 0.13s
# Presolved: 25 rows, 26 columns, 50 nonzeros
# Found heuristic solution: objective 2726.7066000
# Variable types: 0 continuous, 26 integer (0 binary)
#
# Root relaxation: objective 1.205148e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1205.1483000 1205.14830  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.24 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1205.15 2726.71 33680.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.205148300000e+03, best bound 1.205148300000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 19500 rows, 39195 columns and 58500 nonzeros
# Model fingerprint: 0xc2294c4a
# Variable types: 0 continuous, 39195 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33691.273200
# Presolve removed 19477 rows and 39171 columns
# Presolve time: 0.05s
# Presolved: 23 rows, 24 columns, 46 nonzeros
# Found heuristic solution: objective 2364.2273000
# Variable types: 0 continuous, 24 integer (0 binary)
#
# Root relaxation: objective 1.209269e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1209.2690000 1209.26900  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.13 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1209.27 2364.23 33691.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.209269000000e+03, best bound 1.209269000000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 21000 rows, 42210 columns and 63000 nonzeros
# Model fingerprint: 0x9159ecdc
# Variable types: 0 continuous, 42210 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33806.874400
# Presolve removed 20977 rows and 42186 columns
# Presolve time: 0.16s
# Presolved: 23 rows, 24 columns, 46 nonzeros
# Found heuristic solution: objective 2751.1129000
# Variable types: 0 continuous, 24 integer (0 binary)
#
# Root relaxation: objective 1.223611e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1223.6109000 1223.61090  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.28 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1223.61 2751.11 33806.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.223610900000e+03, best bound 1.223610900000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 22500 rows, 45225 columns and 67500 nonzeros
# Model fingerprint: 0xdc8a5d2a
# Variable types: 0 continuous, 45225 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33710.336400
# Presolve removed 22474 rows and 45198 columns
# Presolve time: 0.06s
# Presolved: 26 rows, 27 columns, 52 nonzeros
# Found heuristic solution: objective 3544.8026000
# Variable types: 0 continuous, 27 integer (0 binary)
#
# Root relaxation: objective 1.202282e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1202.2823000 1202.28230  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.14 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1202.28 3544.8 33710.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.202282300000e+03, best bound 1.202282300000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 24000 rows, 48240 columns and 72000 nonzeros
# Model fingerprint: 0xaa835f73
# Variable types: 0 continuous, 48240 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33718.157200
# Presolve removed 23977 rows and 48216 columns
# Presolve time: 0.06s
# Presolved: 23 rows, 24 columns, 46 nonzeros
# Found heuristic solution: objective 2708.3314000
# Variable types: 0 continuous, 24 integer (0 binary)
#
# Root relaxation: objective 1.193272e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1193.2718000 1193.27180  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.30 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1193.27 2708.33 33718.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.193271800000e+03, best bound 1.193271800000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 25500 rows, 51255 columns and 76500 nonzeros
# Model fingerprint: 0x9836e894
# Variable types: 0 continuous, 51255 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33683.696800
# Presolve removed 25479 rows and 51233 columns
# Presolve time: 0.06s
# Presolved: 21 rows, 22 columns, 42 nonzeros
# Found heuristic solution: objective 3266.0992000
# Variable types: 0 continuous, 22 integer (0 binary)
#
# Root relaxation: objective 1.179422e+03, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1179.4215000 1179.42150  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.18 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1179.42 3266.1 33683.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.179421500000e+03, best bound 1.179421500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 27000 rows, 54270 columns and 81000 nonzeros
# Model fingerprint: 0xb224a5ab
# Variable types: 0 continuous, 54270 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33725.978000
# Presolve removed 26709 rows and 53964 columns
# Presolve time: 0.06s
# Presolved: 291 rows, 306 columns, 582 nonzeros
# Variable types: 0 continuous, 306 integer (0 binary)
# Found heuristic solution: objective 2605.7845000
#
# Root relaxation: objective 1.199928e+03, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1199.9275000 1199.92750  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.18 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1199.93 2605.78 33726
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.199927500000e+03, best bound 1.199927500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 28500 rows, 57285 columns and 85500 nonzeros
# Model fingerprint: 0xc2517c29
# Variable types: 0 continuous, 57285 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33710.336400
# Presolve removed 28219 rows and 56989 columns
# Presolve time: 0.04s
# Presolved: 281 rows, 296 columns, 562 nonzeros
# Variable types: 0 continuous, 296 integer (0 binary)
# Found heuristic solution: objective 2359.2402000
#
# Root relaxation: objective 1.180842e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1180.8417000 1180.84170  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.18 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1180.84 2359.24 33710.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.180841700000e+03, best bound 1.180841700000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 30000 rows, 60300 columns and 90000 nonzeros
# Model fingerprint: 0xb74f2969
# Variable types: 0 continuous, 60300 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33722.556400
# Presolve removed 28500 rows and 58785 columns
# Presolve time: 0.03s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3534.1925000
#
# Root relaxation: objective 1.215612e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1215.6123000 1215.61230  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.15 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1215.61 3534.19 33722.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.215612300000e+03, best bound 1.215612300000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 31500 rows, 63315 columns and 94500 nonzeros
# Model fingerprint: 0x54408555
# Variable types: 0 continuous, 63315 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33749.684800
# Presolve removed 30000 rows and 61800 columns
# Presolve time: 0.04s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2720.7526000
#
# Root relaxation: objective 1.193751e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1193.7505000 1193.75050  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.29 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1193.75 2720.75 33749.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.193750500000e+03, best bound 1.193750500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 33000 rows, 66330 columns and 99000 nonzeros
# Model fingerprint: 0xb74412c4
# Variable types: 0 continuous, 66330 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33683.452400
# Presolve removed 31500 rows and 64815 columns
# Presolve time: 0.13s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2707.4545000
#
# Root relaxation: objective 1.202448e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1202.4480000 1202.44800  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.28 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1202.45 2707.45 33683.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.202448000000e+03, best bound 1.202448000000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 34500 rows, 69345 columns and 103500 nonzeros
# Model fingerprint: 0x77b9858d
# Variable types: 0 continuous, 69345 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33798.809200
# Presolve removed 33000 rows and 67830 columns
# Presolve time: 0.05s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2615.4590000
#
# Root relaxation: objective 1.237652e+03, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1237.6515000 1237.65150  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.33 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1237.65 2615.46 33798.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.237651500000e+03, best bound 1.237651500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 36000 rows, 72360 columns and 108000 nonzeros
# Model fingerprint: 0xce642429
# Variable types: 0 continuous, 72360 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33686.874000
# Presolve removed 34500 rows and 70845 columns
# Presolve time: 0.04s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3103.1954000
#
# Root relaxation: objective 1.188542e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1188.5424000 1188.54240  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.21 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1188.54 3103.2 33686.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.188542400000e+03, best bound 1.188542400000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 37500 rows, 75375 columns and 112500 nonzeros
# Model fingerprint: 0x561d21ae
# Variable types: 0 continuous, 75375 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33712.291600
# Presolve removed 36000 rows and 73860 columns
# Presolve time: 0.04s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3915.1921000
#
# Root relaxation: objective 1.202073e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1202.0726000 1202.07260  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.18 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1202.07 3915.19 33712.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.202072600000e+03, best bound 1.202072600000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 39000 rows, 78390 columns and 117000 nonzeros
# Model fingerprint: 0x34930e87
# Variable types: 0 continuous, 78390 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33745.041200
# Presolve removed 37500 rows and 76875 columns
# Presolve time: 0.04s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3412.9816000
#
# Root relaxation: objective 1.190662e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1190.6617000 1190.66170  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.17 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1190.66 3412.98 33745
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.190661700000e+03, best bound 1.190661700000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 40500 rows, 81405 columns and 121500 nonzeros
# Model fingerprint: 0x0e2ac910
# Variable types: 0 continuous, 81405 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33749.196000
# Presolve removed 39000 rows and 79890 columns
# Presolve time: 0.04s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2708.7110000
#
# Root relaxation: objective 1.191652e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1191.6518000 1191.65180  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.20 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1191.65 2708.71 33749.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.191651800000e+03, best bound 1.191651800000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 42000 rows, 84420 columns and 126000 nonzeros
# Model fingerprint: 0xcc44a9d2
# Variable types: 0 continuous, 84420 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33739.175600
# Presolve removed 40500 rows and 82905 columns
# Presolve time: 0.04s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3556.8105000
#
# Root relaxation: objective 1.231787e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1231.7867000 1231.78670  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.32 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1231.79 3556.81 33739.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.231786700000e+03, best bound 1.231786700000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 43500 rows, 87435 columns and 130500 nonzeros
# Model fingerprint: 0xd433b70a
# Variable types: 0 continuous, 87435 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33735.509600
# Presolve removed 42000 rows and 85920 columns
# Presolve time: 0.04s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2680.5826000
#
# Root relaxation: objective 1.168023e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1168.0225000 1168.02250  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.18 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1168.02 2680.58 33735.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.168022500000e+03, best bound 1.168022500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 45000 rows, 90450 columns and 135000 nonzeros
# Model fingerprint: 0x9a07d754
# Variable types: 0 continuous, 90450 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33774.858000
# Presolve removed 43500 rows and 88935 columns
# Presolve time: 0.06s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2314.3939000
#
# Root relaxation: objective 1.162935e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1162.9349000 1162.93490  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.40 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1162.93 2314.39 33774.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.162934900000e+03, best bound 1.162934900000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 46500 rows, 93465 columns and 139500 nonzeros
# Model fingerprint: 0x64fb2a3d
# Variable types: 0 continuous, 93465 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33801.742000
# Presolve removed 45000 rows and 91950 columns
# Presolve time: 0.09s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2724.9296000
#
# Root relaxation: objective 1.202372e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1202.3715000 1202.37150  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.29 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1202.37 2724.93 33801.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.202371500000e+03, best bound 1.202371500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 48000 rows, 96480 columns and 144000 nonzeros
# Model fingerprint: 0x448e26eb
# Variable types: 0 continuous, 96480 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33710.092000
# Presolve removed 46500 rows and 94965 columns
# Presolve time: 0.05s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2738.0382000
#
# Root relaxation: objective 1.209036e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1209.0365000 1209.03650  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.18 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1209.04 2738.04 33710.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.209036500000e+03, best bound 1.209036500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# ...
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33684.430000
# Presolve removed 58500 rows and 119085 columns
# Presolve time: 0.16s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2730.7623000
#
# Root relaxation: objective 1.185764e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1185.7638000 1185.76380  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.56 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1185.76 2730.76 33684.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.185763800000e+03, best bound 1.185763800000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 61500 rows, 123615 columns and 184500 nonzeros
# Model fingerprint: 0xd0f180bd
# Variable types: 0 continuous, 123615 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33731.599200
# Presolve removed 60000 rows and 122100 columns
# Presolve time: 0.07s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3482.3577000
#
# Root relaxation: objective 1.189772e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1189.7723000 1189.77230  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.22 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1189.77 3482.36 33731.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.189772300000e+03, best bound 1.189772300000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 63000 rows, 126630 columns and 189000 nonzeros
# Model fingerprint: 0xc76d4f24
# Variable types: 0 continuous, 126630 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33725.489200
# Presolve removed 61500 rows and 125115 columns
# Presolve time: 0.06s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2724.4963000
#
# Root relaxation: objective 1.203993e+03, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1203.9929000 1203.99290  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.39 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1203.99 2724.5 33725.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203992900000e+03, best bound 1.203992900000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 64500 rows, 129645 columns and 193500 nonzeros
# Model fingerprint: 0xeb29ebbf
# Variable types: 0 continuous, 129645 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33751.151200
# Presolve removed 63000 rows and 128130 columns
# Presolve time: 0.06s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2693.1146000
#
# Root relaxation: objective 1.182109e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1182.1093000 1182.10930  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.22 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1182.11 2693.11 33751.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.182109300000e+03, best bound 1.182109300000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 66000 rows, 132660 columns and 198000 nonzeros
# Model fingerprint: 0xfe53ebf0
# Variable types: 0 continuous, 132660 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33696.405600
# Presolve removed 64500 rows and 131145 columns
# Presolve time: 0.08s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3519.4843000
#
# Root relaxation: objective 1.208903e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1208.9025000 1208.90250  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.26 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1208.9 3519.48 33696.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.208902500000e+03, best bound 1.208902500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 67500 rows, 135675 columns and 202500 nonzeros
# Model fingerprint: 0xb79914ea
# Variable types: 0 continuous, 135675 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33698.605200
# Presolve removed 66000 rows and 134160 columns
# Presolve time: 0.07s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3483.6915000
#
# Root relaxation: objective 1.185052e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1185.0522000 1185.05220  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.32 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1185.05 3483.69 33698.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.185052200000e+03, best bound 1.185052200000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 69000 rows, 138690 columns and 207000 nonzeros
# Model fingerprint: 0x70f1114d
# Variable types: 0 continuous, 138690 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33678.808800
# Presolve removed 67500 rows and 137175 columns
# Presolve time: 0.08s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 2681.3703000
#
# Root relaxation: objective 1.158312e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1158.3123000 1158.31230  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.28 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1158.31 2681.37 33678.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.158312300000e+03, best bound 1.158312300000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 70500 rows, 141705 columns and 211500 nonzeros
# Model fingerprint: 0xf68e8828
# Variable types: 0 continuous, 141705 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33681.986000
# Presolve removed 69000 rows and 140190 columns
# Presolve time: 0.20s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3548.5009000
#
# Root relaxation: objective 1.240919e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1240.9185000 1240.91850  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.48 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1240.92 3548.5 33682
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.240918500000e+03, best bound 1.240918500000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 72000 rows, 144720 columns and 216000 nonzeros
# Model fingerprint: 0x5afad6b1
# Variable types: 0 continuous, 144720 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33675.876000
# Presolve removed 70500 rows and 143205 columns
# Presolve time: 0.18s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3919.3786000
#
# Root relaxation: objective 1.206759e+03, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1206.7590000 1206.75900  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.67 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1206.76 3919.38 33675.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.206759000000e+03, best bound 1.206759000000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 73500 rows, 147735 columns and 220500 nonzeros
# Model fingerprint: 0x54b2c235
# Variable types: 0 continuous, 147735 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33692.739600
# Presolve removed 72000 rows and 146220 columns
# Presolve time: 0.19s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3919.9659000
#
# Root relaxation: objective 1.214345e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1214.3449000 1214.34490  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.37 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1214.34 3919.97 33692.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.214344900000e+03, best bound 1.214344900000e+03, gap 0.0000%
# Discarded solution information
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 75000 rows, 150750 columns and 225000 nonzeros
# Model fingerprint: 0x96abd9b2
# Variable types: 0 continuous, 150750 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 3e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33700.316000
# Presolve removed 73500 rows and 149235 columns
# Presolve time: 0.21s
# Presolved: 1500 rows, 1515 columns, 3000 nonzeros
# Variable types: 0 continuous, 1515 integer (0 binary)
# Found heuristic solution: objective 3312.8777000
#
# Root relaxation: objective 1.227200e+03, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1227.1998000 1227.19980  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.80 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 1227.2 3312.88 33700.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.227199800000e+03, best bound 1.227199800000e+03, gap 0.0000%
# Discarded solution information
# Average Objective:  1201.033706000005
# Average Optimal Capacity at store 0: 89.88
# Average Optimal Capacity at store 1: 51.54
# Average Optimal Capacity at store 2: 98.82
# Average Optimal Capacity at store 3: 66.58
# Average Optimal Capacity at store 4: 53.34
# Average Optimal Capacity at store 5: 61.58
# Average Optimal Capacity at store 6: 114.44
# Average Optimal Capacity at store 7: 110.04
# Average Optimal Capacity at store 8: 99.82
# Average Optimal Capacity at store 9: 98.34
# Average Optimal Capacity at store 10: 82.22
# Average Optimal Capacity at store 11: 95.38
# Average Optimal Capacity at store 12: 120.02
# Average Optimal Capacity at store 13: 121.86
# Average Optimal Capacity at store 14: 115.24
