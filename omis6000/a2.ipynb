# %%
from gurobipy import GRB
import gurobipy as gb

# %%
import pandas as pd

# %%
# Create the model
model = gb.Model("FIBA")

# Read the dataset
df = pd.read_csv('/Users/frieda/Desktop/BasketballPlayers.csv', index_col='Number')

# Create decision variables
x = model.addVars(150, vtype=gb.GRB.BINARY, name="Player")

# Set the objective function
model.setObjective(gb.quicksum(df.iloc[i, 1:8].sum() * x[i] for i in range(150)), gb.GRB.MAXIMIZE)

# Capacity constraint
model.addConstr(gb.quicksum(x[i] for i in range(150)) == 21, "Total Players")

# Position constraints
guard_indices = df[(df['Position'] == 'G') | (df['Position'] == 'G/F')].index.tolist()
model.addConstr(gb.quicksum(x[i] for i in guard_indices) >= 0.3 * 21, "Guard Position")

forward_center_indices = df[(df['Position'] == 'F') | (df['Position'] == 'C') | (df['Position'] == 'F/C')].index.tolist()
if forward_center_indices:
    model.addConstr(gb.quicksum(x[i] for i in forward_center_indices if i < 150) >= 0.4 * 21, "Forward/Center Position")

# Average score constraints
for j in range(7):
    model.addConstr((gb.quicksum(df.iloc[i, j+1] * x[i] for i in range(150)) / 21) >= 2.05, f"Average Score {j}")

# Constraint: if any 20-24, not all 72-78
for i in range(19, 24):
    model.addConstr(x[i] <= 1 - gb.quicksum(x[j] for j in range(71, 78)), f"If any 20-24, not all 72-78")

# Constraint: if any 105-114, at least one 45-49 and at least one 60-69
for i in range(104, 114):
    model.addConstr(x[i] <= gb.quicksum(x[j] for j in range(44, 49)), f"If any 105-114, at least 45-49")
    model.addConstr(x[i] <= gb.quicksum(x[j] for j in range(64, 69)), f"If any 105-114, at least 65-69")

# We need at least one player from every 10 players
for i in range(14):
    model.addConstr(gb.quicksum(x[i*10 + j] for j in range(10)) >= 1, f"At least one player from group {i}")

# Optimize the model
model.optimize()

# Print the objective and decision variables
model.printAttr('X')

# Print the model status
print("Model Status: ", model.status)

# Count and print the number of guards invited
selected = [i for i, var in enumerate(model.getVars()) if var.x != 0]
guards_count = sum(1 for i in selected if df.iloc[i]['Position'] in ['G', 'G/F'])
print(f'Number of G and G/F: {guards_count}')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-14
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 49 rows, 150 columns and 1649 nonzeros
# Model fingerprint: 0xcbe95b5d
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve time: 0.00s
# Presolved: 49 rows, 150 columns, 1310 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: objective 3.600000e+02, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     360.0000000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
#
#     Variable            X
# -------------------------
#    Player[4]            1
#    Player[6]            1
#   Player[10]            1
#   Player[25]            1
#   Player[36]            1
#   Player[46]            1
#   Player[55]            1
#   Player[66]            1
#   Player[73]            1
#   Player[89]            1
#   Player[94]            1
#  Player[103]            1
#  Player[109]            1
#  Player[110]            1
#  Player[117]            1
#  Player[127]            1
#  Player[131]            1
#  Player[132]            1
#  Player[133]            1
#  Player[143]            1
#  Player[147]            1
# Model Status:  2
# Number of G and G/F: 11

# %%
#2h:

def smallest(number):

    x = model.addVars(150, vtype=gb.GRB.BINARY, name="Player")

    model.setObjective(gb.quicksum(((df.iloc[i,1:8]).sum())*x[i] for i in range(150)), gb.GRB.MAXIMIZE)

    model.addConstr(gb.quicksum(x[i] for i in range(150)) == 21, "Total Players")

    guard_indices = df[(df['Position'] == 'G') | (df['Position'] == 'G/F')].index.tolist()
    model.addConstr(gb.quicksum(x[i] for i in guard_indices) >= 0.3 * 21, "Guard Position")

    index_fc = df[(df['Position'] == 'F') | (df['Position'] == 'C') | (df['Position'] == 'F/C')].index.tolist()
    model.addConstr(gb.quicksum(x[i-1] for i in index_fc) >= number * 0.4, "Forward/Center Position")

    forward_center_indices = df[(df['Position'] == 'F') | (df['Position'] == 'C') | (df['Position'] == 'F/C')].index.tolist()
    if forward_center_indices:
        model.addConstr(gb.quicksum(x[i] for i in forward_center_indices if i < 150) >= 0.4 * 21, "Forward/Center Position")

    for j in range(7):
        model.addConstr((gb.quicksum(df.iloc[i, j+1] * x[i] for i in range(150)) / 21) >= 2.05, f"Average Score {j}")

    for i in range(19, 24):
        model.addConstr(x[i] <= 1 - gb.quicksum(x[j] for j in range(71, 78)), f"If any 20-24, not all 72-78")

    for i in range(104, 114): 
        model.addConstr(x[i] <= gb.quicksum(x[j] for j in range(44, 49)), f"If any 105-114, at least 45-49")
        model.addConstr(x[i] <= gb.quicksum(x[j] for j in range(64, 69)), f"If any 105-114, at least 65-69")

    for i in range(14):
        model.addConstr(gb.quicksum(x[i*10 + j] for j in range(10)) >= 1, f"At least one player from group {i}")


    return model

# initial number of smallest number of invitations 
num_of_invite = 21

# Iterate over the range of invitations from the initial value down to 0
for number in range(num_of_invite, 0, -1):
    # Set the number of invitations to the current value
    model = smallest(number)
    
    # Solve the model
    model.optimize()
    
    # Check feasibility status
    if model.status != gb.GRB.Status.OPTIMAL:
        # Infeasible solution found, break the loop
        break
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 99 rows, 300 columns and 3380 nonzeros
# Model fingerprint: 0x87f2ac10
# Variable types: 0 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.09s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 49 rows and 150 columns
# Presolve time: 0.03s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.24 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 149 rows, 450 columns and 5111 nonzeros
# Model fingerprint: 0xaaa0d65b
# Variable types: 0 continuous, 450 integer (450 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.13s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 99 rows and 300 columns
# Presolve time: 0.03s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.23 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 199 rows, 600 columns and 6842 nonzeros
# Model fingerprint: 0x716b00a9
# Variable types: 0 continuous, 600 integer (600 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.07s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 149 rows and 450 columns
# Presolve time: 0.02s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.21 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 249 rows, 750 columns and 8573 nonzeros
# Model fingerprint: 0xa0015e73
# Variable types: 0 continuous, 750 integer (750 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.10s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 199 rows and 600 columns
# Presolve time: 0.06s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.31 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 299 rows, 900 columns and 10304 nonzeros
# Model fingerprint: 0xab47847b
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.06s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 249 rows and 750 columns
# Presolve time: 0.06s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.17 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 349 rows, 1050 columns and 12035 nonzeros
# Model fingerprint: 0x94eb192c
# Variable types: 0 continuous, 1050 integer (1050 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.10s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 299 rows and 900 columns
# Presolve time: 0.05s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.19 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 399 rows, 1200 columns and 13766 nonzeros
# Model fingerprint: 0xea2e1c9d
# Variable types: 0 continuous, 1200 integer (1200 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.03s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 349 rows and 1050 columns
# Presolve time: 0.07s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.24 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 449 rows, 1350 columns and 15497 nonzeros
# Model fingerprint: 0x5a7172fe
# Variable types: 0 continuous, 1350 integer (1350 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.03s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 399 rows and 1200 columns
# Presolve time: 0.07s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.15 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 499 rows, 1500 columns and 17228 nonzeros
# Model fingerprint: 0x410b57cc
# Variable types: 0 continuous, 1500 integer (1500 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.07s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 449 rows and 1350 columns
# Presolve time: 0.08s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.19 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 549 rows, 1650 columns and 18959 nonzeros
# Model fingerprint: 0x1624470f
# Variable types: 0 continuous, 1650 integer (1650 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.15s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 499 rows and 1500 columns
# Presolve time: 0.20s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.42 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 599 rows, 1800 columns and 20690 nonzeros
# Model fingerprint: 0x7614068a
# Variable types: 0 continuous, 1800 integer (1800 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.26s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 549 rows and 1650 columns
# Presolve time: 0.13s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.45 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 649 rows, 1950 columns and 22421 nonzeros
# Model fingerprint: 0xc32d2322
# Variable types: 0 continuous, 1950 integer (1950 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.14s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 599 rows and 1800 columns
# Presolve time: 0.11s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.34 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 699 rows, 2100 columns and 24152 nonzeros
# Model fingerprint: 0xbaf921d6
# Variable types: 0 continuous, 2100 integer (2100 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.09s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 649 rows and 1950 columns
# Presolve time: 0.09s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.43 seconds (0.06 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 749 rows, 2250 columns and 25883 nonzeros
# Model fingerprint: 0x2a0088f8
# Variable types: 0 continuous, 2250 integer (2250 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.09s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 699 rows and 2100 columns
# Presolve time: 0.09s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.26 seconds (0.06 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 799 rows, 2400 columns and 27614 nonzeros
# Model fingerprint: 0xae76cbea
# Variable types: 0 continuous, 2400 integer (2400 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.14s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 749 rows and 2250 columns
# Presolve time: 0.10s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.31 seconds (0.06 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 849 rows, 2550 columns and 29345 nonzeros
# Model fingerprint: 0x5d4dbf64
# Variable types: 0 continuous, 2550 integer (2550 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.05s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 799 rows and 2400 columns
# Presolve time: 0.13s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.23 seconds (0.07 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 899 rows, 2700 columns and 31076 nonzeros
# Model fingerprint: 0x395d52b7
# Variable types: 0 continuous, 2700 integer (2700 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.08s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 849 rows and 2550 columns
# Presolve time: 0.10s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.29 seconds (0.07 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 949 rows, 2850 columns and 32807 nonzeros
# Model fingerprint: 0x2fa06691
# Variable types: 0 continuous, 2850 integer (2850 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.06s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 899 rows and 2700 columns
# Presolve time: 0.13s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.25 seconds (0.08 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 999 rows, 3000 columns and 34538 nonzeros
# Model fingerprint: 0xeb8ff28e
# Variable types: 0 continuous, 3000 integer (3000 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.12s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 949 rows and 2850 columns
# Presolve time: 0.13s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.37 seconds (0.08 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 1049 rows, 3150 columns and 36269 nonzeros
# Model fingerprint: 0x7017d0a8
# Variable types: 0 continuous, 3150 integer (3150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-01, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.06s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 999 rows and 3000 columns
# Presolve time: 0.15s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.27 seconds (0.08 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 1099 rows, 3300 columns and 38000 nonzeros
# Model fingerprint: 0x5837102f
# Variable types: 0 continuous, 3300 integer (3300 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e-01, 2e+01]
#
# MIP start from previous solve produced solution with objective 360 (0.09s)
# Loaded MIP start from previous solve with objective 360
#
# Presolve removed 1049 rows and 3150 columns
# Presolve time: 0.13s
# Presolved: 50 rows, 150 columns, 1392 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       360.00000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.29 seconds (0.09 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%

# %%
# Print the result
print("Smallest number of invitations before the model yields an infeasible solution:", num_of_invite+1)
# Out:
# Smallest number of invitations before the model yields an infeasible solution: 22
