# %%
from gurobipy import GRB
import gurobipy as gb

# %%
import pandas as pd

# %%
# Create the model
model = gb.Model("FIBA")

# Read the dataset
df = pd.read_csv('/Users/frieda/Desktop/BasketballPlayers.csv', index_col='Number')

# Create decision variables
x = model.addVars(150, vtype=gb.GRB.BINARY, name="Player")

# Set the objective function
model.setObjective(gb.quicksum(df.iloc[i, 1:8].sum() * x[i] for i in range(150)), gb.GRB.MAXIMIZE)

# Add constraints

# Capacity constraint
model.addConstr(gb.quicksum(x[i] for i in range(150)) == 21, "Total Players")

# Position constraints
guard_indices = df[(df['Position'] == 'G') | (df['Position'] == 'G/F')].index.tolist()
model.addConstr(gb.quicksum(x[i] for i in guard_indices) >= 0.3 * 21, "Guard Position")

forward_center_indices = df[(df['Position'] == 'F') | (df['Position'] == 'C') | (df['Position'] == 'F/C')].index.tolist()
if forward_center_indices:
    model.addConstr(gb.quicksum(x[i] for i in forward_center_indices if i < 150) >= 0.4 * 21, "Forward/Center Position")

# Average score constraints
for j in range(7):
    model.addConstr((gb.quicksum(df.iloc[i, j+1] * x[i] for i in range(150)) / 21) >= 2.05, f"Average Score {j}")

# Constraint: if any 20-24, not all 72-78
for i in range(19, 24):
    model.addConstr(x[i] <= 1 - gb.quicksum(x[j] for j in range(71, 78)), f"If any 20-24, not all 72-78")

# Constraint: if any 105-114, at least one 45-49 and at least one 60-69
for i in range(104, 114):
    model.addConstr(x[i] <= gb.quicksum(x[j] for j in range(44, 49)), f"If any 105-114, at least 45-49")
    model.addConstr(x[i] <= gb.quicksum(x[j] for j in range(64, 69)), f"If any 105-114, at least 65-69")

# We need at least one player from every 10 players
for i in range(14):
    model.addConstr(gb.quicksum(x[i*10 + j] for j in range(10)) >= 1, f"At least one player from group {i}")

# Optimize the model
model.optimize()

# Print the objective and decision variables
model.printAttr('X')

# Print the model status
print("Model Status: ", model.status)

# Count and print the number of guards invited
selected = [i for i, var in enumerate(model.getVars()) if var.x != 0]
guards_count = sum(1 for i in selected if df.iloc[i]['Position'] in ['G', 'G/F'])
print(f'Number of G and G/F: {guards_count}')
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 49 rows, 150 columns and 1649 nonzeros
# Model fingerprint: 0xcbe95b5d
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve time: 0.01s
# Presolved: 49 rows, 150 columns, 1310 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: objective 3.600000e+02, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     360.0000000  360.00000  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+02, best bound 3.600000000000e+02, gap 0.0000%
#
#     Variable            X
# -------------------------
#    Player[4]            1
#    Player[6]            1
#   Player[10]            1
#   Player[25]            1
#   Player[36]            1
#   Player[46]            1
#   Player[55]            1
#   Player[66]            1
#   Player[73]            1
#   Player[89]            1
#   Player[94]            1
#  Player[103]            1
#  Player[109]            1
#  Player[110]            1
#  Player[117]            1
#  Player[127]            1
#  Player[131]            1
#  Player[132]            1
#  Player[133]            1
#  Player[143]            1
#  Player[147]            1
# Model Status:  2
# Number of G and G/F: 11

# %%
#2h:

def smallest(number):

    # Create decision variables
    x = model.addVars(150, vtype=gb.GRB.BINARY, name="Player")

    # The objective function
    model.setObjective(gb.quicksum(((df.iloc[i,1:8]).sum())*x[i] for i in range(150)), gb.GRB.MAXIMIZE)

    # Add constraints:
    model.addConstr(gb.quicksum(x[i] for i in range(150)) == number, "Capacity Constraint")

    index_guard = df[(df['Position'] == 'G') | (df['Position'] == 'G/F')].index.tolist()
    model.addConstr(gb.quicksum(x[i-1] for i in index_guard) >= number * 0.3, "Guard Position")

    index_fc = df[(df['Position'] == 'F') | (df['Position'] == 'C') | (df['Position'] == 'F/C')].index.tolist()
    model.addConstr(gb.quicksum(x[i-1] for i in index_fc) >= number * 0.4, "Forward/Center Position")

    for j in range(7):
        model.addConstr(gb.quicksum(x[i] * df.iloc[i,j+1] for i in range(150)) / number >= 2.05, f"Average Score {j}")

    for i in range(19, 24):
        for j in range(71, 78):
            model.addConstr(x[i] <= 1 - x[j], f"If 20-24, not all 72-78")

    for i in range(104, 114):
        model.addConstr(x[i] <= gb.quicksum(x[j] for j in range(44, 49)), f"If 105-114, at least one 45-49")
        model.addConstr(x[i] <= gb.quicksum(x[j] for j in range(59, 69)), f"If 105-114, at least one 60-69")

    for i in range(14):
        model.addConstr(gb.quicksum(x[i*10 + j] for j in range(10)) >= 1, f"At least one from group {i}")

    return model

# initial number of smallest number of invitations 
num_of_invite = 21

# Iterate over the range of invitations from the initial value down to 0
for number in range(num_of_invite, 0, -1):
    # Set the number of invitations to the current value
    model = smallest(number)
    
    # Solve the model
    model.optimize()
    
    # Check feasibility status
    if model.status != gb.GRB.Status.OPTIMAL:
        # Infeasible solution found, break the loop
        break
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 128 rows, 300 columns and 3379 nonzeros
# Model fingerprint: 0xacbffcd2
# Variable types: 0 continuous, 300 integer (300 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 362 (0.21s)
# Loaded MIP start from previous solve with objective 362
#
# Presolve removed 49 rows and 150 columns
# Presolve time: 0.02s
# Presolved: 79 rows, 150 columns, 1391 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       362.00000  362.00000  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.29 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 362
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.620000000000e+02, best bound 3.620000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 207 rows, 450 columns and 5109 nonzeros
# Model fingerprint: 0xf40af51a
# Variable types: 0 continuous, 450 integer (450 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 345 (0.04s)
# Loaded MIP start from previous solve with objective 345
#
# Presolve removed 128 rows and 300 columns
# Presolve time: 0.02s
# Presolved: 79 rows, 150 columns, 1391 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       345.00000  345.00000  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.11 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 345
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.450000000000e+02, best bound 3.450000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 286 rows, 600 columns and 6839 nonzeros
# Model fingerprint: 0xc276aa24
# Variable types: 0 continuous, 600 integer (600 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 328 (0.05s)
# Loaded MIP start from previous solve with objective 328
#
# Presolve removed 207 rows and 450 columns
# Presolve time: 0.03s
# Presolved: 79 rows, 150 columns, 1391 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       328.00000  328.00000  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.13 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 328
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.280000000000e+02, best bound 3.280000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 365 rows, 750 columns and 8569 nonzeros
# Model fingerprint: 0x4194922c
# Variable types: 0 continuous, 750 integer (750 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 311 (0.04s)
# Loaded MIP start from previous solve with objective 311
#
# Presolve removed 286 rows and 600 columns
# Presolve time: 0.03s
# Presolved: 79 rows, 150 columns, 1391 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       311.00000  311.00000  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.13 seconds (0.02 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 311
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.110000000000e+02, best bound 3.110000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 444 rows, 900 columns and 10299 nonzeros
# Model fingerprint: 0x10aea1f2
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 294 (0.05s)
# Loaded MIP start from previous solve with objective 294
#
# Presolve removed 365 rows and 750 columns
# Presolve time: 0.11s
# Presolved: 79 rows, 150 columns, 1391 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       294.00000  294.00000  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.20 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 294
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.940000000000e+02, best bound 2.940000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 523 rows, 1050 columns and 12029 nonzeros
# Model fingerprint: 0xd9e027af
# Variable types: 0 continuous, 1050 integer (1050 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 277 (0.16s)
# Loaded MIP start from previous solve with objective 277
#
# Presolve removed 444 rows and 900 columns
# Presolve time: 0.06s
# Presolved: 79 rows, 150 columns, 1391 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       277.00000  277.00000  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.31 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 277
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.770000000000e+02, best bound 2.770000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 602 rows, 1200 columns and 13759 nonzeros
# Model fingerprint: 0xd4ed6443
# Variable types: 0 continuous, 1200 integer (1200 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 260 (0.11s)
# Loaded MIP start from previous solve with objective 260
#
# Presolve removed 523 rows and 1050 columns
# Presolve time: 0.08s
# Presolved: 79 rows, 150 columns, 1391 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       260.00000  260.00000  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.27 seconds (0.04 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 260
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+02, best bound 2.600000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 681 rows, 1350 columns and 15489 nonzeros
# Model fingerprint: 0x07f44afe
# Variable types: 0 continuous, 1350 integer (1350 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 242 (0.05s)
# Loaded MIP start from previous solve with objective 242
#
# Presolve removed 602 rows and 1200 columns
# Presolve time: 0.08s
# Presolved: 79 rows, 150 columns, 1391 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: cutoff, 26 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       242.00000  242.00000  0.00%     -    0s
#
# Explored 1 nodes (26 simplex iterations) in 0.18 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 242
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.420000000000e+02, best bound 2.420000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 760 rows, 1500 columns and 17219 nonzeros
# Model fingerprint: 0x1d259837
# Variable types: 0 continuous, 1500 integer (1500 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
#
# Presolve removed 681 rows and 1350 columns
# Presolve time: 0.07s
# Presolved: 79 rows, 150 columns, 1391 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: infeasible, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.17 seconds (0.06 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 0
# No other solutions better than -1e+100
#
# Model is infeasible
# Best objective -, best bound -, gap -

# %%
# Print the result
print("Smallest number of invitations before the model yields an infeasible solution:", num_of_invite+1)

model.computeIIS()
infeasible_constraint = [constr.ConstrName for constr in model.getConstrs() if constr.IISConstr]
print("constraint(s) cannot be satisfied:", infeasible_constraint)
# Out:
# Smallest number of invitations before the model yields an infeasible solution: 22
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 20.2.0 20C69)
#
# CPU model: Intel(R) Core(TM) i5-5257U CPU @ 2.70GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
#
# Computing Irreducible Inconsistent Subsystem (IIS)...
#
#            Constraints          |            Bounds           |  Runtime
#       Min       Max     Guess   |   Min       Max     Guess   |
# --------------------------------------------------------------------------
#         0       760         -         0         0         0           0s
#        15        15        15         0         0         0           0s
#
# IIS computed: 15 constraints, 0 bounds
# IIS runtime: 0.12 seconds (0.01 work units)
# constraint(s) cannot be satisfied: ['Capacity Constraint', 'At least one from group 0', 'At least one from group 1', 'At least one from group 2', 'At least one from group 3', 'At least one from group 4', 'At least one from group 5', 'At least one from group 6', 'At least one from group 7', 'At least one from group 8', 'At least one from group 9', 'At least one from group 10', 'At least one from group 11', 'At least one from group 12', 'At least one from group 13']
