# %%
import pandas as pd

# %%
import seaborn as sns# use this to create stat table like scatter plot

# %% [markdown]
# Pandas is one of the most common and frequently used tools for data analysis. It contains data structures and manipulation tools which make data cleaning, organizing, and analysis easy and efficient. This library is typically used with other libraries like NumPy, SciPy, statsmadels, scikit-learn, and matplotlib.
#
# While NumPy works best with homogeneous data, pandas is designed to work with tabular, heterogeneous data. The two primary components of pandas are series and DataFrames. You can think of a series as a column of data, and a DataFrame as a collection of series. You can apply operations to a DataFrame as a whole, or to individual columns – this makes it easy to work with various data types.
#
# You can create DataFrames from scratch, but in the real world we often bring data into a DataFrame from another source – for example, a SQL database, or data files like .csv or .xlsx.
#
# To install pandas, you can either do so through Anaconda by navigating to your environment and searching through the list of available packages, or directly in Jupyter:
#
# Pandas is typically imported with the alias pd. This is an industry best practice and I recommend you use this as well.

# %%
df = pd.read_csv('/Users/frieda/Desktop/schulich/MBAN6110S/messy_data.csv')

# %%
df #shown number of rows and number of columns
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
sns.histplot(df['Income'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Count'>

# %%
sns.boxplot(df['Income'])
# Out:
# /Users/frieda/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Income'>

# %%
sns.boxplot(data=df, y = 'Income', x = 'Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Income'>

# %%
sns.scatterplot(data=df, x = 'Age', y = 'Income')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %%
sns.lmplot(data = df, x = 'Age', y = 'Income', fit_reg = True)

# %%
df.drop(df[df['Age']==120].index,axis =0,inplace=True)

# %%
df[df['Age']==56].index
# Out:
# Int64Index([0, 6, 41], dtype='int64')

# %%
sns.lmplot(data = df, x = 'Age', y = 'Income', fit_reg = True)

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       98 non-null     int64
#  1   Income    88 non-null     float64
#  2   Gender    98 non-null     object
#  3   Product   93 non-null     object
#  4   Quantity  98 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.6+ KB

# %%
df['Product']=df['Product'].fillna("Others")#fill in null with others

# %%
df.max()
df[df['Income']>290000]
# Out:
#     Age    Income Gender Product  Quantity
# 99   61  300000.0   Male       B         4

# %%
df.drop(99,axis=0,inplace=True)

# %%
sns.boxplot(df['Income'])
# Out:
# /Users/frieda/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Income'>

# %%
# df=df.rename(columns={'Age':'Customer_Age'}) 
# change the title of this column to something more specific: Customer_Age.
# We can do this by using the pandas rename function. The syntax for this is:
#  object.rename(parameters).

# %%
df.info() #Print a concise summary of a DataFrame.
# always start with info function, to check non null count and type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       105 non-null    int64
#  1   Income    94 non-null     float64
#  2   Gender    105 non-null    object
#  3   Product   100 non-null    object
#  4   Quantity  105 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.2+ KB

# %%
df.describe(

)# check normal distribution: mean and median is the same 
# next func we do is describe, we can use include='all' to show all rows
# Out:
#               Age         Income   Quantity
# count  105.000000      94.000000  105.00000
# mean    42.076190   52867.862808    3.20000
# std     15.940813   29896.579420    1.44382
# min     18.000000   20901.331720    1.00000
# 25%     31.000000   37814.315255    2.00000
# 50%     41.000000   48760.369705    3.00000
# 75%     55.000000   61644.277868    5.00000
# max    120.000000  300000.000000    5.00000

# %%
df.describe(include = 'all')#unique and top and frequancy is shown 
#astype()can help to change the data type
# Out:
#                Age         Income  Gender Product   Quantity
# count   105.000000      94.000000     105     100  105.00000
# unique         NaN            NaN       2       4        NaN
# top            NaN            NaN  Female       D        NaN
# freq           NaN            NaN      58      28        NaN
# mean     42.076190   52867.862808     NaN     NaN    3.20000
# std      15.940813   29896.579420     NaN     NaN    1.44382
# min      18.000000   20901.331720     NaN     NaN    1.00000
# 25%      31.000000   37814.315255     NaN     NaN    2.00000
# 50%      41.000000   48760.369705     NaN     NaN    3.00000
# 75%      55.000000   61644.277868     NaN     NaN    5.00000
# max     120.000000  300000.000000     NaN     NaN    5.00000

# %%
df[df['Product'].isnull()]# Detect missing values for an array-like object
# check if product is null and return df[boolean], so return value
# Out:
#     Age       Income  Gender Product  Quantity
# 1    46  36399.18997  Female     NaN         1
# 34   64  40845.16974  Female     NaN         2
# 45   31  30330.13661    Male     NaN         5
# 86   43  63312.67422  Female     NaN         4
# 94   42  67538.11470    Male     NaN         1

# %%
df['Product'].isnull() # check if product is null and return boolean
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# Name: Product, Length: 105, dtype: bool

# %%
df[df['Income']>40000] #64rows so means 65 people income beyond 40000
# Out:
#      Age        Income  Gender Product  Quantity
# 0     56   59544.57663  Female       D         3
# 2     32   57140.63881  Female       D         2
# 3     60   69554.91903    Male       C         5
# 4     25   53173.80518  Female       D         2
# 5     38   58955.66969  Female       A         2
# ..   ...           ...     ...     ...       ...
# 95    24   63099.75454  Female       B         5
# 96    26   53084.75201    Male       D         3
# 99    61  300000.00000    Male       B         4
# 102   31   53254.05089    Male       B         2
# 104   60   69554.91903    Male       C         5
#
# [64 rows x 5 columns]

# %%
summary_D = df[df['Product'] == 'D'].describe()
summary_D
# Out:
#              Age        Income   Quantity
# count  28.000000     26.000000  28.000000
# mean   43.107143  49876.379810   2.642857
# std    13.982368  14148.860233   1.445665
# min    18.000000  28602.816730   1.000000
# 25%    32.750000  38643.331093   1.750000
# 50%    41.500000  48629.797555   2.000000
# 75%    56.250000  57109.709432   4.000000
# max    64.000000  94154.951250   5.000000

# %%
type(df[df['Product'] == 'D'].describe())#dataframe means a collection of columns
# Out:
# pandas.core.frame.DataFrame

# %%
print(df['Income'].mean(),df['Income'].median())
# Out:
# 52867.86280776595 48760.369705

# %%
df[df['Income'].isnull()]
# Out:
#      Age  Income  Gender Product  Quantity
# 11    41     NaN  Female       A         5
# 12    53     NaN    Male       B         1
# 28    42     NaN    Male       D         1
# 32    33     NaN    Male       D         2
# 39    38     NaN    Male       A         1
# 42    35     NaN    Male       B         1
# 43    21     NaN    Male       B         2
# 64    59     NaN  Female       B         2
# 66    46     NaN  Female       C         5
# 73    31     NaN  Female       A         4
# 103   21     NaN    Male       B         2

# %%
df2 = df.copy()
df2['Income'] = df2['Income'].fillna(df2['Income'].mean())
# fillna() method replaces the NULL values with a specified value
df2['Income']
# Out:
# 0      59544.57663
# 1      36399.18997
# 2      57140.63881
# 3      69554.91903
# 4      53173.80518
#           ...
# 100    37341.55459
# 101    35516.63492
# 102    53254.05089
# 103            NaN
# 104    69554.91903
# Name: Income, Length: 105, dtype: float64

# %%
df[df['Product'] == 'D'].head()#head function to only shows the first few lines
# Out:
#    Age       Income  Gender Product  Quantity
# 0   56  59544.57663  Female       D         3
# 2   32  57140.63881  Female       D         2
# 4   25  53173.80518  Female       D         2
# 6   56  36554.97225    Male       D         1
# 8   40  72034.11928    Male       D         2

# %%
df.iloc[50] #filter data by list/table location 
#select rows and columns from a Pandas DataFrame
#  or a Series using integer-based indexing
# index position 50
# Out:
# Age                  45
# Income      33556.01307
# Gender           Female
# Product               C
# Quantity              5
# Name: 50, dtype: object

# %%
df.loc[50]
#It's worth noting that df.loc[50] accesses the row with label/index value 50, 
# which is different from df.iloc[50] that accesses the row at integer position 50.
# Out:
# Age                  45
# Income      33556.01307
# Gender           Female
# Product               C
# Quantity              5
# Name: 50, dtype: object

# %%
#column_iloc = df.iloc[:, 1]
#column_loc = df.loc[:, 'Age']

# %%
df.set_index('Gender')
# Out:
#         Age       Income Product  Quantity
# Gender
# Female   56  59544.57663       D         3
# Female   46  36399.18997     NaN         1
# Female   32  57140.63881       D         2
# Male     60  69554.91903       C         5
# Female   25  53173.80518       D         2
# ...     ...          ...     ...       ...
# Male     61  37341.55459       D         5
# Female   55  35516.63492       A         3
# Male     31  53254.05089       B         2
# Male     21          NaN       B         2
# Male     60  69554.91903       C         5
#
# [105 rows x 4 columns]

# %%
# DataFrame.set_index(keys, *, drop=True,
# append=False, inplace=False, verify_integrity=False)

df.set_index('Gender').loc['Female']
# filter female only by using loc
# Out:
#         Age       Income Product  Quantity
# Gender
# Female   56  59544.57663       D         3
# Female   46  36399.18997     NaN         1
# Female   32  57140.63881       D         2
# Female   25  53173.80518       D         2
# Female   38  58955.66969       A         2
# Female   36  48320.18269       A         4
# Female   28  33141.52498       D         3
# Female   28  64250.08093       B         4
# Female   41          NaN       A         5
# Female   41  54902.67836       B         4
# Female   55  35516.63492       A         3
# Female   19  52257.33617       B         4
# Female   50  89502.92331       C         2
# Female   29  34623.63667       C         4
# Female   39  38269.28261       D         2
# Female   61  56359.14605       A         3
# Female   44  84308.38974       C         3
# Female   59  74343.80749       A         4
# Female   32  63449.45576       C         5
# Female   64  40845.16974     NaN         2
# Female   61  45257.51155       D         5
# ...
